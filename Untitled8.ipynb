# %% [markdown]
# <a href="https://colab.research.google.com/github/Nusrahkhan/1st-Data-Analysis-Project/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing** **files**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/StudentPerformanceFactors.csv")

# %% [markdown]
# #**Preprocessing** **of** **data**

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %% [markdown]
# ## **Sanity** **check** **of** **data**

# %%
df.shape
# Out:
# (6054, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6054 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6054 non-null   int64
#  1   Attendance                  6054 non-null   int64
#  2   Parental_Involvement        6054 non-null   object
#  3   Access_to_Resources         6054 non-null   object
#  4   Extracurricular_Activities  6054 non-null   object
#  5   Sleep_Hours                 6054 non-null   int64
#  6   Previous_Scores             6054 non-null   int64
#  7   Motivation_Level            6054 non-null   object
#  8   Internet_Access             6054 non-null   object
#  9   Tutoring_Sessions           6054 non-null   int64
#  10  Family_Income               6054 non-null   object
#  11  Teacher_Quality             6054 non-null   object
#  12  School_Type                 6054 non-null   object
# ...

# %% [markdown]
# ## **Finding** **missing** **values**

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# ## **finding** **duplicates**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## **Finding** **garbage** **values**

# %%
for i in df.select_dtypes(include=['object']).columns:
  print(df[i].value_counts())
  print("***"*10)
# Out:
# Parental_Involvement
# Medium    3098
# High      1745
# Low       1211
# Name: count, dtype: int64
# ******************************
# Access_to_Resources
# Medium    3048
# High      1805
# Low       1201
# Name: count, dtype: int64
# ******************************
# Extracurricular_Activities
# Yes    3605
# No     2449
# Name: count, dtype: int64
# ******************************
# Motivation_Level
# Medium    3077
# Low       1775
# High      1202
# Name: count, dtype: int64
# ******************************
# Internet_Access
# Yes    5592
# No      462
# Name: count, dtype: int64
# ******************************
# Family_Income
# Medium    2458
# Low       2441
# High      1155
# Name: count, dtype: int64
# ******************************
# Teacher_Quality
# Medium    3668
# High      1790
# Low        596
# Name: count, dtype: int64
# ******************************
# School_Type
# Public     4215
# Private    1839
# Name: count, dtype: int64
# ******************************
# ...

# %% [markdown]
# # **Exploratory** **Data** **Analysis**

# %%
df.describe()

#Count: The total number of non-missing values. If a column has a lower count than expected, it indicates missing values that may need to be handled.
#Mean: The average value, which helps gauge the central tendency of data in a column. Outliers or incorrect data points may skew this, so it’s useful for spotting irregularities.
#Standard Deviation (std): Shows how spread out the values are from the mean. A high standard deviation might suggest a wide range of values, or possible outliers.
#Min and Max: These give the smallest and largest values in each column. If the minimum or maximum seems unreasonable (e.g., negative values where they shouldn’t exist), it’s a sign you need to investigate further.
#Quartiles (25%, 50%, and 75%): These give insights into the data distribution, especially useful for spotting skewness or detecting unexpected patterns.
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6054.000000  6054.000000  6054.000000      6054.000000
# mean       20.019326    79.972580     7.034357        75.111827
# std         5.776193    11.498579     1.469827        14.355942
# min         4.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        87.750000
# max        36.000000   100.000000    10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6054.000000        6054.000000  6054.000000
# mean            1.293360           2.961843    66.981500
# std             0.983676           1.029563     3.225434
# min             0.000000           0.000000    59.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.describe(include='object')
# Out:
#        Parental_Involvement Access_to_Resources Extracurricular_Activities  \
# count                  6054                6054                       6054
# unique                    3                   3                          2
# top                  Medium              Medium                        Yes
# freq                   3098                3048                       3605
#
#        Motivation_Level Internet_Access Family_Income Teacher_Quality  \
# count              6054            6054          6054            6054
# unique                3               2             3               3
# top              Medium             Yes        Medium          Medium
# freq               3077            5592          2458            3668
#
#        School_Type Peer_Influence Learning_Disabilities  \
# count         6054           6054                  6054
# unique           2              3                     2
# top         Public       Positive                    No
# ...

# %% [markdown]
# ## **boxplot** **for** **identifying** **outliers**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in df.select_dtypes(include="number").columns:
  sns.boxplot(data=df, x=i)
  plt.show()

# %% [markdown]
# ## **scatter** **plot**

# %%
for i in df.select_dtypes(include="number").columns:
  sns.scatterplot(data=df, x=i, y="Exam_Score")
  plt.show()

# %% [markdown]
# ## **Encoding** **Of** **Data**

# %%
# prompt: print column name of object data type

for col in df.select_dtypes(include=['object']).columns:
  print(col)
# Out:
# Parental_Involvement
# Access_to_Resources
# Extracurricular_Activities
# Motivation_Level
# Internet_Access
# Family_Income
# Teacher_Quality
# School_Type
# Peer_Influence
# Learning_Disabilities
# Parental_Education_Level
# Distance_from_Home
# Gender

# %%
pd.get_dummies(data=df, columns=["Parental_Involvement",
"Access_to_Resources",
"Extracurricular_Activities",
"Motivation_Level",
"Internet_Access",
"Family_Income",
"Teacher_Quality",
"School_Type",
"Peer_Influence",
"Learning_Disabilities",
"Parental_Education_Level",
"Distance_from_Home",
"Gender"],drop_first=True)
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0                23          84            7               73
# 1                19          64            8               59
# 2                24          98            7               91
# 3                29          89            8               98
# 4                19          92            6               65
# ...             ...         ...          ...              ...
# 6602             25          69            7               76
# 6603             23          76            8               81
# 6604             20          90            6               65
# 6605             10          86            6               91
# 6606             15          67            9               94
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score  \
# 0                     0                  3          67
# 1                     2                  4          61
# ...

# %% [markdown]
# ## idk

# %%
from sklearn.preprocessing import OneHotEncoder

# Identify categorical columns (replace with your actual categorical column names)
categorical_cols = ['Hours_Studied']

# Create a OneHotEncoder object
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore') # sparse=False for array output

# Fit the encoder on the categorical columns and transform them
encoded_data = encoder.fit_transform(X[categorical_cols])

# Create a DataFrame from the encoded data
encoded_df = pd.DataFrame(encoded_data, columns=encoder.get_feature_names_out(categorical_cols))

# Drop the original categorical columns and concatenate the encoded DataFrame
X = X.drop(columns=categorical_cols)
X = pd.concat([X, encoded_df], axis=1)

# %% [markdown]
# # Make X and Y variables

# %%
X = df.drop(columns=["Exam_Score"])
y = df["Exam_Score"]

# %% [markdown]
# # Training data

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# #Using Linear Regression model

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
# prompt: write code for linear regression model

# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-1700a40bcbd0> in <cell line: 5>()
#       3 # Create and train the linear regression model
#       4 model = LinearRegression()
# ----> 5 model.fit(X_train, y_train)
#       6
#       7 # Make predictions on the test set
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     607         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     608
# --> 609         X, y = self._validate_data(
#     610             X,
#     611             y,
#
# ...

# %%
# prompt: generate a scattered plot using appropriate columns as x and y axis

import matplotlib.pyplot as plt

# Assuming 'Hours_Studied' and 'Exam_Score' are suitable columns for the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df_encoded['Hours_Studied'], df_encoded['Exam_Score'])
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Scatter Plot of Hours Studied vs. Exam Score')
plt.grid(True)
plt.show()

# %%
# Re-run the VIF calculation on the cleaned data
from statsmodels.stats.outliers_influence import variance_inflation_factor
import numpy as np

X_numeric = X.select_dtypes(include=[np.number])

vif_data = pd.DataFrame()
vif_data["feature"] = X_numeric.columns
vif_data["VIF"] = [variance_inflation_factor(X_numeric.values, i) for i in range(X_numeric.shape[1])]
print(vif_data)
# Out:
#              feature       VIF
# 0      Hours_Studied  1.001403
# 1         Attendance  1.003074
# 2        Sleep_Hours  1.000877
# 3    Previous_Scores  1.002045
# 4  Tutoring_Sessions  1.001038
# 5  Physical_Activity  1.001432

# %%
import matplotlib.pyplot as plt

# Assuming 'Hours_Studied' and 'Exam_Score' are suitable columns for the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df_encoded['Hours_Studied'], df_encoded['Exam_Score'])
plt.xlabel('Hours Studied')
plt.ylabel('Exam Score')
plt.title('Scatter Plot of Hours Studied vs. Exam Score')
plt.grid(True)
plt.show()

# %%
from sklearn.model_selection import cross_val_score

cross_val_scores = cross_val_score(LinearRegression(), X, y, cv=5, scoring='r2')
print("Cross-validated R^2 scores:", cross_val_scores)
print("Average R^2 score:", cross_val_scores.mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-2ab797d457d0> in <cell line: 3>()
#       1 from sklearn.model_selection import cross_val_score
#       2
# ----> 3 cross_val_scores = cross_val_score(LinearRegression(), X, y, cv=5, scoring='r2')
#       4 print("Cross-validated R^2 scores:", cross_val_scores)
#       5 print("Average R^2 score:", cross_val_scores.mean())
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     211                     )
#     212                 ):
# --> 213                     return func(*args, **kwargs)
#     214             except InvalidParameterError as e:
#     215                 # When the function is just a wrapper around an estimator, we allow
#
# ...
